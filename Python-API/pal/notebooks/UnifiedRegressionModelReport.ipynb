# %%
import hana_ml
from hana_ml import dataframe
from data_load_utils import Settings
from hana_ml.algorithms.pal.unified_regression import UnifiedRegression

url, port, user, pwd = Settings.load_config("../../config/e2edata.ini")
connection_context = dataframe.ConnectionContext(url, port, user, pwd)
# Out:
# ModuleNotFoundError: No module named 'shapely'. Required by graph/spatial module.

# %% [markdown]
# ## Load Data

# %%
def createTableAndLoadData(table_name, create_table_sql, data):
    cursor = connection_context.connection.cursor()
    cursor.execute(create_table_sql) # .format(table_name)
    cursor.executemany("INSERT INTO {} VALUES ({})".format(table_name,', '.join(['?']*len(data[0]))), data)
    
def createTableAndLoadDataAsBatch(table_name_list, create_table_sql_list, data_list):
    for i in range(0, len(table_name_list)):
        try:
            createTableAndLoadData(table_name_list[i], create_table_sql_list[i], data_list[i])
        except Exception as e:
            print('{} table is exists.'.format(table_name_list[i]))

# %%
func_list = ['dt', 'exp', 'geo', 'glm', 'hgbt',
             'log', 'mlp', 'mlr', 'pol', 'rdt',
             'svm']

tableDef = {
    'DATA_UNIR_DT_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_DT_TBL(' +
        '"OUTLOOK" VARCHAR(20),' +
        '"TEMP" INTEGER,' +
        '"HUMIDITY" DOUBLE,' +
        '"WINDY" VARCHAR(10),' +
        '"CLASS" DOUBLE);',
    'DATA_UNIR_EXP_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_EXP_TBL(' +
        '"ID" INTEGER, ' +
        '"X1" DOUBLE, ' +
        '"X2" DOUBLE, ' +
        '"Y" DOUBLE);',
    'DATA_UNIR_GEO_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_GEO_TBL(' +
        '"ID" INTEGER, ' +
        '"X1" DOUBLE, ' +
        '"Y" DOUBLE);',
    'DATA_UNIR_GLM_TBL' : 
        'CREATE COLUMN TABLE DATA_UNIR_GLM_TBL(' +
        '"ID" INTEGER, ' +
        '"X" INTEGER, ' +
        '"Y" INTEGER);',
    'DATA_UNIR_HGBT_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_HGBT_TBL(' +
        '"ATT1" VARCHAR(10), ' +
        '"ATT2" DOUBLE, ' +
        '"ATT3" DOUBLE, ' +
        '"ATT4" DOUBLE, ' +
        '"TARGET" DOUBLE);',
    'DATA_UNIR_LOG_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_LOG_TBL(' +
        '"ID" INTEGER, ' +
        '"X1" DOUBLE, ' +
        '"Y" DOUBLE);',     
    'DATA_UNIR_MLP_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_MLP_TBL(' +
        '"V000" INTEGER, ' +
        '"V001" DOUBLE, ' +
        '"V002" VARCHAR(10), ' +
        '"V003" INTEGER, ' +
        '"T001" DOUBLE, ' +
        '"T002" DOUBLE, ' +
        '"T003" DOUBLE);',
    'DATA_UNIR_MLR_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_MLR_TBL(' +
        '"ID" INTEGER, ' +
        '"X1" DOUBLE, ' +
        '"X2" VARCHAR (100), ' +
        '"X3" INTEGER, ' +
        '"Y" DOUBLE);',
    'DATA_UNIR_POL_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_POL_TBL(' +
        '"ID" INTEGER, ' +
        '"X1" DOUBLE, ' +
        '"Y" DOUBLE);',
    'DATA_UNIR_RDT_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_RDT_TBL(' +
        '"OUTLOOK" VARCHAR(20), ' +
        '"TEMP" INTEGER, ' +
        '"HUMIDITY" DOUBLE, ' +
        '"WINDY" VARCHAR(10), '
        '"CLASS" INTEGER);',
    'DATA_UNIR_SVM_TBL' :
        'CREATE COLUMN TABLE DATA_UNIR_SVM_TBL (' +
        '"ID" INTEGER, ' +
        '"ATTRIBUTE1" DOUBLE, ' + 
        '"ATTRIBUTE2" DOUBLE, ' + 
        '"ATTRIBUTE3" DOUBLE, ' +
        '"ATTRIBUTE4" VARCHAR(10),' +
        '"LABEL" INTEGER);'
}

data_list = [[('Sunny', 75, 70, 'Yes', 1),
              ('Sunny', 80, 90, 'Yes', 0),
              ('Sunny', 85, 85, 'No', 0),
              ('Sunny', 72, 95, 'No', 0),
              ('Sunny', 69, 70, 'No', 1),
              ('Overcast', 72, 90, 'Yes', 1),
              ('Overcast', 83, 78, 'No', 0),
              ('Overcast', 64, 65, 'Yes', 1),
              ('Overcast', 81, 75, 'No', 1),
              ('Rain', 71, 80, 'Yes', 0),
              ('Rain', 65, 70, 'Yes', 0),
              ('Rain', 75, 80, 'No', 1),
              ('Rain', 68, 80, 'No', 1),
              ('Rain', 70, 96, 'No', 0)],
             [(0, 0.13, 0.33, 0.5),
              (1, 0.14, 0.34, 0.15),
              (2, 0.15, 0.36, 0.25),
              (3, 0.16, 0.35, 0.35),
              (4, 0.17, 0.37, 0.45),
              (5, 0.18, 0.38, 0.55),
              (6, 0.19, 0.39, 0.65),
              (7, 0.19, 0.31, 0.75),
              (8, 0.11, 0.32, 0.85),
              (9, 0.12, 0.33, 0.95)],
             [(0, 1, 5),
              (1, 2, 20),
              (2, 3, 43),
              (3, 4, 89),
              (4, 5, 166),
              (5, 6, 247),
              (6, 7, 403)],
             [(1, -1, 0),
              (2, -1, 0),
              (3, 0, 1),
              (4, 0, 1),
              (5, 0, 1),
              (6, 0, 1),
              (7, 1, 2),
              (8, 1, 2),
              (9, 1, 2)],
             [('19.76', 6235,  100.0, 100.0, 25.10),
              ('17.85', 46230, 43.67, 84.53, 19.23),
              ('19.96', 7360,  65.51, 81.57, 21.42),
              ('16.80', 28715, 45.16, 93.33, 18.11),
              ('18.20', 21934, 49.20, 83.07, 19.24),
              ('16.71', 1337,  74.84, 94.99, 19.31),
              ('18.81', 17881, 70.66, 92.34, 20.07),
              ('20.74', 2319,  63.93, 95.08, 24.35),
              ('16.56', 18040, 14.45, 61.24, 17.60),
              ('18.55', 1147,  68.58, 97.90, 20.13),
              ('17.40', 2176,  53.33, 97.50, 18.40),
              ('17.62', 13267, 25.16, 56.86, 18.96),
              ('21.24', 3581,  35.76, 63.58, 25.75),
              ('18.23', 15104, 47.72, 95.29, 19.40),
              ('16.86', 47009, 17.21, 100.0, 18.64),
              ('17.45', 10139, 43.15, 89.40, 19.10),
              ('17.66', 6147,  67.73, 92.54, 20.00),
              ('18.30', 23089, 33.27, 67.53, 19.31),
              ('16.58', 20550, 26.61, 98.32, 20.49),
              ('17.51', 9450,  61.35, 86.72, 17.07),
              ('21.17', 1028,  100.0, 100.0, 20.61),
              ('16.92', 3848,  5.350, 65.58, 15.73),
              ('16.96', 15656, 20.53, 93.72, 18.70),
              ('18.24', 7725,  50.59, 96.63, 18.99)],
             [(0, 1, 5),
              (1, 2, 20),
              (2, 3, 43),
              (3, 4, 89),
              (4, 5, 166),
              (5, 6, 247),
              (6, 7, 403)],
             [(1, 1.71, 'AC', 0, 12.7, 2.8, 3.06),
              (10, 1.78, 'CA', 5, 12.1, 8.0, 2.65),
              (17, 2.36, 'AA', 6, 10.1, 2.8, 3.24),
              (12, 3.15, 'AA', 2, 28.1, 5.6, 2.24),
              (7, 1.05, 'CA', 3, 19.8, 7.1, 1.98),
              (6, 1.50, 'CA', 2, 23.2, 4.9, 2.12),
              (9, 1.97, 'CA', 6, 24.5, 4.2, 1.05),
              (5, 1.26, 'AA', 1, 13.6, 5.1, 2.78),
              (12, 2.13, 'AC', 4, 13.2, 1.9, 1.34),
              (18, 1.87, 'AC', 6, 25.5, 3.6, 2.14)],
             [(0, 0.0, 'A', 1, -6.879),
              (1, 0.50, 'A', 1, -3.449),
              (2, 0.54, 'B', 1, 6.635),
              (3, 1.04, 'B', 1, 11.844),
              (4, 1.50, 'A', 1, 2.786),
              (5, 0.04, 'B', 2, 2.389),
              (6, 2.00, 'A', 2, -0.011),
              (7, 2.04, 'B', 2, 8.839),
              (8, 1.54, 'B', 1, 4.689),
              (9, 1.00, 'A', 2, -5.507)],
             [(0, 1, 5),
              (1, 2, 20),
              (2, 3, 43),
              (3, 4, 89),
              (4, 5, 166),
              (5, 6, 247),
              (6, 7, 403)],
             [('Sunny', 75, 70.1, 'Yes', 1),
              ('Sunny', 80, 90.1, 'Yes', 0),
              ('Sunny', 85, 85.1, 'No', 0),
              ('Sunny', 72, 95.1, 'No', 0),
              ('Sunny', 69, 70.1, 'No', 1),
              ('Overcast', 72, 90.1, 'Yes', 1),
              ('Overcast', 83, 78.1, 'No', 0),
              ('Overcast', 64, 65.1, 'Yes', 1),
              ('Overcast', 81, 75.1, 'No', 1),
              ('Rain', 71, 80.1, 'Yes', 0),
              ('Rain', 65, 70.1, 'Yes', 0),
              ('Rain', 75, 80.1, 'No', 1),
              ('Rain', 68, 80.1, 'No', 1),
              ('Rain', 70, 96.1, 'No', 0)],
             [(0,1,10,100,'A',1),
              (1,1.1,10.1,100,'A',1),
              (2,1.2,10.2,100,'A',1),
              (3,1.3,10.4,100,'A',1),
              (4,1.2,10.3,100,'AB',1),
              (5,4,40,400,'AB',1),
              (6,4.1,40.1,400,'AB',1),
              (7,4.2,40.2,400,'AB',1),
              (8,4.3,40.4,400,'AB',2),
              (9,4.2,40.3,400,'AB',2),
              (10,9,90,900,'B',2),
              (11,9.1,90.1,900,'A',2),
              (12,9.2,90.2,900,'B',2),
              (13,9.3,90.4,900,'A',2),
              (14,9.2,90.3,900,'A',2)]]

# %%
table_name_list = list(tableDef.keys())
create_table_sql_list = list(tableDef.values())
createTableAndLoadDataAsBatch(table_name_list, create_table_sql_list, data_list)
function_index = -1
# Out:
# DATA_UNIR_DT_TBL table is exists.
# DATA_UNIR_EXP_TBL table is exists.
# DATA_UNIR_GEO_TBL table is exists.
# DATA_UNIR_GLM_TBL table is exists.
# DATA_UNIR_HGBT_TBL table is exists.
# DATA_UNIR_LOG_TBL table is exists.
# DATA_UNIR_MLP_TBL table is exists.
# DATA_UNIR_MLR_TBL table is exists.
# DATA_UNIR_POL_TBL table is exists.
# DATA_UNIR_RDT_TBL table is exists.
# DATA_UNIR_SVM_TBL table is exists.

# %% [markdown]
# ## Decision Tree Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#      OUTLOOK  TEMP  HUMIDITY WINDY  CLASS
# 0      Sunny    75      70.0   Yes    1.0
# 1      Sunny    80      90.0   Yes    0.0
# 2      Sunny    85      85.0    No    0.0
# 3      Sunny    72      95.0    No    0.0
# 4      Sunny    69      70.0    No    1.0
# 5   Overcast    72      90.0   Yes    1.0
# 6   Overcast    83      78.0    No    0.0
# 7   Overcast    64      65.0   Yes    1.0
# 8   Overcast    81      75.0    No    1.0
# 9       Rain    71      80.0   Yes    0.0
# 10      Rain    65      70.0   Yes    0.0
# 11      Rain    75      80.0    No    1.0
# 12      Rain    68      80.0    No    1.0
# 13      Rain    70      96.0    No    0.0

# %%
dt_params = dict(model_format = 'json',# pmml
                 allow_missing_dependent = True,#
                 percentage = 1,#
                 use_surrogate = True,#
                 split_threshold = 1e-5,
                 min_records_of_parent = 2,
                 min_records_of_leaf = 1,
                 thread_ratio = 0.5)
udtr = UnifiedRegression(func = 'DecisionTree', **dt_params)
udtr.fit(data = tbl, partition_method = 'random',
         partition_random_state=2, output_partition_result = True)

# %%
udtr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          0       None  {"CurrentVersion":"VERSION1.3","DataDictionary...

# %%
# udtr.generate_html_report('DecisionTree')

# %%
udtr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:29:16&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;-3&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;-3.499999999999999&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;3&lt;/td&gt;&lt;/tr&gt;&lt;/tbody&gt;&lt;/table&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/ ...

# %% [markdown]
# ## Exponential Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    ID    X1    X2     Y
# 0   0  0.13  0.33  0.50
# 1   1  0.14  0.34  0.15
# 2   2  0.15  0.36  0.25
# 3   3  0.16  0.35  0.35
# 4   4  0.17  0.37  0.45
# 5   5  0.18  0.38  0.55
# 6   6  0.19  0.39  0.65
# 7   7  0.19  0.31  0.75
# 8   8  0.11  0.32  0.85
# 9   9  0.12  0.33  0.95

# %%
exp_params = dict(adjusted_r2 = True,
                  decomposition = 'lu')
uexpr = UnifiedRegression(func = 'ExponentialRegression',
                          **exp_params)
uexpr.fit(data = tbl, key = 'ID',
          label = 'Y',
          partition_method = 'random',
          partition_random_state = 2)

# %%
uexpr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          1       None  <PMML version="4.0" xmlns="http://www.dmg.org/...

# %%
# uexpr.generate_html_report('ExponentialRegression')

# %%
uexpr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:30:50&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;-1.1359911166721637&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;0.21922545501178392&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.40403570828657376&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;0.3371894808164267&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;0.06197531150916212&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;-1.7544582892960934&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;0.2489484113409084&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&g ...

# %% [markdown]
# ## Geometric Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    ID   X1      Y
# 0   0  1.0    5.0
# 1   1  2.0   20.0
# 2   2  3.0   43.0
# 3   3  4.0   89.0
# 4   4  5.0  166.0
# 5   5  6.0  247.0
# 6   6  7.0  403.0

# %%
geo_params = dict(decomposition='lu', adjusted_r2=False)
ugeor = UnifiedRegression(func = 'GeometricRegression',
                          **geo_params)
par_params = dict(partition_method='random',
                  training_percent=0.5,
                  output_partition_result=True,
                  partition_random_state=2)
ugeor.fit(data = tbl,
          key = 'ID',
          label = 'Y',
          **par_params)

# %%
ugeor.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          1       None  <PMML version="4.0" xmlns="http://www.dmg.org/...

# %%
# ugeor.generate_html_report('GeometricRegression')

# %%
ugeor.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:33:32&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.9976352511248125&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;6.1152998067781&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.07721083220526175&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;12.422186409269798&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;58.74637007172249&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;0.9934930301198033&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;7.66461806430839&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;0.051533 ...

# %% [markdown]
# ## Generalized Linear Models Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    ID  X  Y
# 0   1 -1  0
# 1   2 -1  0
# 2   3  0  1
# 3   4  0  1
# 4   5  0  1
# 5   6  0  1
# 6   7  1  2
# 7   8  1  2
# 8   9  1  2

# %%
glm_params = dict(solver='irls', family='poisson', link='LOG',
                  tol = 1e-8, handle_missing_fit = 'skip',
                  max_iter = 100, significance_level = 0.05,
                  quasilikelihood = False,
                  thread_ratio=0.5)
par_params = dict(partition_method='random',
                  training_percent=0.5,
                  output_partition_result=True,
                  partition_random_state=2)
uglmr = UnifiedRegression(func = 'GLM', **glm_params)
uglmr.fit(data = tbl, key = 'ID',
          label = 'Y', **par_params)

# %%
uglmr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          0       None  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 1          1       None  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 2          2       None  <PMML version="4.0" xmlns="http://www.dmg.org/...

# %%
# uglmr.generate_html_report('GLM')

# %%
uglmr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:34:27&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.9378879319590757&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;0.26247406627841396&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.3693063937629154&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;0.28633534503099733&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;0.07060071733985067&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;0.8973080475056717&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;0.26570795498037064&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt ...

# %% [markdown]
# ## HGBT Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#      ATT1     ATT2    ATT3    ATT4  TARGET
# 0   19.76   6235.0  100.00  100.00   25.10
# 1   17.85  46230.0   43.67   84.53   19.23
# 2   19.96   7360.0   65.51   81.57   21.42
# 3   16.80  28715.0   45.16   93.33   18.11
# 4   18.20  21934.0   49.20   83.07   19.24
# 5   16.71   1337.0   74.84   94.99   19.31
# 6   18.81  17881.0   70.66   92.34   20.07
# 7   20.74   2319.0   63.93   95.08   24.35
# 8   16.56  18040.0   14.45   61.24   17.60
# 9   18.55   1147.0   68.58   97.90   20.13
# 10  17.40   2176.0   53.33   97.50   18.40
# 11  17.62  13267.0   25.16   56.86   18.96
# 12  21.24   3581.0   35.76   63.58   25.75
# 13  18.23  15104.0   47.72   95.29   19.40
# 14  16.86  47009.0   17.21  100.00   18.64
# 15  17.45  10139.0   43.15   89.40   19.10
# 16  17.66   6147.0   67.73   92.54   20.00
# 17  18.30  23089.0   33.27   67.53   19.31
# 18  16.58  20550.0   26.61   98.32   20.49
# 19  17.51   9450.0   61.35   86.72   17.07
# 20  21.17   1028.0  100.00  100.00   20.61
# 21  16.92   3848.0    5.35   65.58   15.73
# 22  16.96  15656.0   20.53   93.72   18.70
# 23  18.24   7725.0   50.59   96.63   18.99

# %%
hgbt_params = dict(max_depth=6,
                   alpha=0,
                   base_score=0,
                   col_subsample_split=1,
                   col_subsample_tree=1,
                   lamb=1,
                   min_sample_weight_leaf=1,
                   min_samples_leaf=1,
                   max_w_in_split=0,
                   subsample=1,
                   split_method='Exact',
                   resampling_method='cv',
                   fold_num=5,
                   evaluation_metric='rmse',
                   ref_metric='mae',
                   search_strategy='grid',
                   random_state=1,
                   param_range = dict(
                       n_estimators=[10, 2, 20],
                       learning_rate=[0.1, 0.2, 1.0],
                       split_threshold=[0,0.2,1.0]
                   ))
par_params = dict(partition_method='random',
                  training_percent=0.5,
                  partition_random_state=2,
                  output_partition_result=True)
uhgbtr = UnifiedRegression(func='HybridGradientBoostingTree',
                           **hgbt_params)
uhgbtr.fit(data = tbl,
           label = 'TARGET',
           **par_params)

# %%
uhgbtr.model_.collect()
# Out:
#     ROW_INDEX  PART_INDEX                                      MODEL_CONTENT
# 0           1          -1  {"model_version":"2.0","nclass":1,"nrow":12,"p...
# 1           2           0  {"height":0,"nnode":1,"nodes":[{"ch":[],"gn":4...
# 2           3           1  {"height":0,"nnode":1,"nodes":[{"ch":[],"gn":2...
# 3           4           2  {"height":0,"nnode":1,"nodes":[{"ch":[],"gn":1...
# 4           5           3  {"height":1,"nnode":3,"nodes":[{"ch":[1,2],"gn...
# 5           6           4  {"height":2,"nnode":5,"nodes":[{"ch":[1,2],"gn...
# 6           7           5  {"height":3,"nnode":7,"nodes":[{"ch":[1,2],"gn...
# 7           8           6  {"height":3,"nnode":7,"nodes":[{"ch":[1,2],"gn...
# 8           9           7  {"height":2,"nnode":5,"nodes":[{"ch":[1,2],"gn...
# 9          10           8  {"height":2,"nnode":5,"nodes":[{"ch":[1,2],"gn...
# 10         11           9  {"height":1,"nnode":3,"nodes":[{"ch":[1,2],"gn...

# %%
# uhgbtr.generate_html_report('HybridGradientBoostingTree')

# %%
uhgbtr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:35:43&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.10403993641159193&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;1.4347076864758748&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.06896375553560062&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;4.8161505550820785&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;3.4658447408510313&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;-0.2949614589688867&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;1.8616779369297556&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt; ...

# %% [markdown]
# ## Logarithmic Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    ID   X1      Y
# 0   0  1.0    5.0
# 1   1  2.0   20.0
# 2   2  3.0   43.0
# 3   3  4.0   89.0
# 4   4  5.0  166.0
# 5   5  6.0  247.0
# 6   6  7.0  403.0

# %%
log_params = dict(decomposition='lu',
                  thread_ratio=0.5)
par_params = dict(partition_method='random',
                  training_percent=0.5,
                  partition_random_state=2,
                  output_partition_result=True)
ulogr = UnifiedRegression(func='LogarithmicRegression',
                          **log_params)
ulogr.fit(data = tbl,
          key = 'ID',
          label = 'Y',
          **par_params)

# %%
ulogr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          1       None  <PMML version="4.0" xmlns="http://www.dmg.org/...

# %%
# ulogr.generate_html_report('LogarithmicRegression')

# %%
ulogr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:36:57&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.8587196370281518&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;57.86023728391282&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;1.275971411286282&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;104.35985326790225&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;4623.317571096756&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;0.4879038799336548&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;67.99498195526458&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;0.48758 ...

# %% [markdown]
# ##  Multi-layer Perceptron (MLP)

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    V000  V001 V002  V003  T001  T002  T003
# 0     1  1.71   AC     0  12.7   2.8  3.06
# 1    10  1.78   CA     5  12.1   8.0  2.65
# 2    17  2.36   AA     6  10.1   2.8  3.24
# 3    12  3.15   AA     2  28.1   5.6  2.24
# 4     7  1.05   CA     3  19.8   7.1  1.98
# 5     6  1.50   CA     2  23.2   4.9  2.12
# 6     9  1.97   CA     6  24.5   4.2  1.05
# 7     5  1.26   AA     1  13.6   5.1  2.78
# 8    12  2.13   AC     4  13.2   1.9  1.34
# 9    18  1.87   AC     6  25.5   3.6  2.14

# %%
mlp_params = dict(thread_ratio=0.5,
                  hidden_layer_size = [10,5],
                  activation='sin_asymmetric',
                  output_activation='sin_asymmetric',
                  learning_rate=0.01, batch_size=1,
                  momentum=0.00001, training_style='batch',
                  max_iter=10000, normalization='z-transform',
                  weight_init='normal')
par_params = dict(partition_method='random', training_percent=0.5,
                  output_partition_result=True)
umlpr = UnifiedRegression(func='MLP', **mlp_params)
umlpr.fit(data = tbl, label = "T001",
          **par_params)

# %%
umlpr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          1       None  {"CurrentVersion":"1.0","DataDictionary":[{"da...
# 1          2       None  m":5,"weight":-0.1626542576649863},{"from":6,"...

# %%
# umlpr.generate_html_report('MLP')

# %%
umlpr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:37:44&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;-6.597475877106191&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;7.140757751538655&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.5720285255139976&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;12.665191047714636&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;62.435258927432145&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;-40.44666683977174&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;7.901598504570588&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;0.578 ...

# %% [markdown]
# ## Linear Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    ID    X1 X2  X3       Y
# 0   0  0.00  A   1  -6.879
# 1   1  0.50  A   1  -3.449
# 2   2  0.54  B   1   6.635
# 3   3  1.04  B   1  11.844
# 4   4  1.50  A   1   2.786
# 5   5  0.04  B   2   2.389
# 6   6  2.00  A   2  -0.011
# 7   7  2.04  B   2   8.839
# 8   8  1.54  B   1   4.689
# 9   9  1.00  A   2  -5.507

# %%
mlr_params = dict(solver = 'qr',
                  adjusted_r2=False,
                  thread_ratio=0.5)
par_params = dict(partition_method='random', training_percent=0.7,
                  partition_random_state=2,
                  output_partition_result=True)
umlr = UnifiedRegression(func='LinearRegression', **mlr_params)
umlr.fit(data = tbl, key = 'ID',
         label = 'Y',
         **par_params)

# %%
umlr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          1       None  <PMML version="4.0" xmlns="http://www.dmg.org/...

# %%
# umlr.generate_html_report('LinearRegression')

# %%
umlr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:38:32&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.871459247598903&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;2.0088082000000003&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;12.260003987804756&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;5.329849599999999&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;9.551661310681718&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;0.7774293644548433&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;3.09057621013974&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;0.718800 ...

# %% [markdown]
# ## Polynomial Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#    ID   X1      Y
# 0   0  1.0    5.0
# 1   1  2.0   20.0
# 2   2  3.0   43.0
# 3   3  4.0   89.0
# 4   4  5.0  166.0
# 5   5  6.0  247.0
# 6   6  7.0  403.0

# %%
polr_params = dict(decomposition='lu',
                   thread_ratio=0.5,
                   degree=3)
par_params = dict(partition_method='random',
                  training_percent=0.5,
                  partition_random_state=2,
                  output_partition_result=True)
upolr = UnifiedRegression(func='PolynomialRegression', **polr_params)
upolr.fit(data = tbl,
          key = 'ID', label = 'Y',
          **par_params)

# %%
upolr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          1       None  <PMML version="4.0" xmlns="http://www.dmg.org/...

# %%
# upolr.generate_html_report('PolynomialRegression')

# %%
upolr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:39:39&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.9866014815481047&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;9.770627333333316&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.12060823380642609&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;21.437025999999946&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;164.02813708701123&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;0.9818316238734942&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;12.807346996431823&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;0.0 ...

# %% [markdown]
# ## RandomForest Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#      OUTLOOK  TEMP  HUMIDITY WINDY  CLASS
# 0      Sunny    75      70.1   Yes      1
# 1      Sunny    80      90.1   Yes      0
# 2      Sunny    85      85.1    No      0
# 3      Sunny    72      95.1    No      0
# 4      Sunny    69      70.1    No      1
# 5   Overcast    72      90.1   Yes      1
# 6   Overcast    83      78.1    No      0
# 7   Overcast    64      65.1   Yes      1
# 8   Overcast    81      75.1    No      1
# 9       Rain    71      80.1   Yes      0
# 10      Rain    65      70.1   Yes      0
# 11      Rain    75      80.1    No      1
# 12      Rain    68      80.1    No      1
# 13      Rain    70      96.1    No      0

# %%
rdtr_params = dict(thread_ratio=0.5, n_estimators=300,
                   allow_missing_dependent = True,
                   sample_fraction=1,
                   max_features=3, random_state=2,
                   split_threshold=1e-5,
                   min_samples_leaf=1)
par_params = dict(partition_method='random', training_percent=0.5,
                  partition_random_state=2)
urdtr = UnifiedRegression(func='RandomForest', **rdtr_params)
urdtr.fit(data = tbl,
          label = 'CLASS',
          **par_params)

# %%
urdtr.model_.collect()
# Out:
#      ROW_INDEX  PART_INDEX                                      MODEL_CONTENT
# 0            0          -1  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 1            1           0  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 2            2           1  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 3            3           2  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 4            4           3  <PMML version="4.0" xmlns="http://www.dmg.org/...
# ..         ...         ...                                                ...
# 296        296         295  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 297        297         296  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 298        298         297  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 299        299         298  <PMML version="4.0" xmlns="http://www.dmg.org/...
# 300        300         299  <PMML version="4.0" xmlns="http://www.dmg.org/...
#
# [301 rows x 3 columns]

# %%
# urdtr.generate_html_report('RandomForest')

# %%
urdtr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:40:51&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;-0.4535680600256671&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;0.5872561428571429&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.8316101428571429&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;0.804762&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;0.36045052488385715&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;-0.47183964327575034&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;0.6003753200156192&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;1.3702643 ...

# %% [markdown]
# ## Support Vector Regression

# %%
function_index += 1
tbl = connection_context.table(table_name_list[function_index])
tbl.collect()
# Out:
#     ID  ATTRIBUTE1  ATTRIBUTE2  ATTRIBUTE3 ATTRIBUTE4  LABEL
# 0    0         1.0        10.0       100.0          A      1
# 1    1         1.1        10.1       100.0          A      1
# 2    2         1.2        10.2       100.0          A      1
# 3    3         1.3        10.4       100.0          A      1
# 4    4         1.2        10.3       100.0         AB      1
# 5    5         4.0        40.0       400.0         AB      1
# 6    6         4.1        40.1       400.0         AB      1
# 7    7         4.2        40.2       400.0         AB      1
# 8    8         4.3        40.4       400.0         AB      2
# 9    9         4.2        40.3       400.0         AB      2
# 10  10         9.0        90.0       900.0          B      2
# 11  11         9.1        90.1       900.0          A      2
# 12  12         9.2        90.2       900.0          B      2
# 13  13         9.3        90.4       900.0          A      2
# 14  14         9.2        90.3       900.0          A      2

# %%
svr_params = dict(thread_ratio = 0.5,
                  c = 100,
                  handle_missing=True,
                  kernel='rbf',
                  regression_eps=0.1,
                  scale_label=True,
                  scale_info='standardization',
                  shrink=True,
                  compression=True)#compression defaults to True?
par_params = dict(partition_method='random',
                  training_percent=0.8,
                  partition_random_state=2)
usvr = UnifiedRegression(func='SVM', **svr_params)
usvr.fit(data = tbl,
         key='ID',
         label = 'LABEL',
         **par_params)

# %%
usvr.model_.collect()
# Out:
#    ROW_INDEX PART_INDEX                                      MODEL_CONTENT
# 0          0       None  {"C":100.0,"CONTENT":"{\"impute_model\":{\"col...

# %%
# usvr.generate_html_report('SVM')

# %%
usvr.generate_notebook_iframe_report()
# Out:
# In order to review the unified regression model report better, you need to adjust the size of the left area or hide the left area temporarily!
#             <iframe
#                 width="100%"
#                 height="800px"
#                 srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=en style=margin-top:10px&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;title&gt;Unified Regression Model Report&lt;/title&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.13.1/css/all.min.css&gt;&lt;link rel=stylesheet href=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/css/adminlte.min.css&gt;&lt;script src=https://cdn.jsdelivr.net/npm/jquery@3.2.1/dist/jquery.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js&gt;&lt;/script&gt;&lt;script src=https://cdn.jsdelivr.net/npm/admin-lte@3.0.5/dist/js/adminlte.min.js&gt;&lt;/script&gt;&lt;/head&gt;&lt;body class=&quot;sidebar-mini layout-fixed layout-navbar-fixed&quot;&gt;&lt;div class=&quot;wrapper container-fluid&quot;&gt;&lt;nav class=&quot;main-header navbar navbar-expand navbar-white navbar-light&quot;&gt;&lt;ul class=navbar-nav&gt;&lt;li class=nav-item&gt;&lt;a class=nav-link data-widget=pushmenu role=button&gt;&lt;i class=&quot;fas fa-bars&quot;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Unified Regression Model&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;ul class=&quot;navbar-nav ml-auto&quot;&gt;&lt;li class=&quot;nav-item d-none d-sm-inline-block&quot;&gt;&lt;a class=nav-link&gt;Created Time: 2020-11-17 17:43:23&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;aside class=&quot;main-sidebar sidebar-light-primary elevation-4&quot;&gt;&lt;div style=&quot;text-align: center;&quot;&gt;&lt;a class=brand-link&gt;&lt;span class=&quot;brand-text font-weight-bold&quot;&gt;Model Report&lt;/span&gt;&lt;/a&gt;&lt;/div&gt;&lt;div class=sidebar&gt;&lt;nav class=mt-2&gt;&lt;ul class=&quot;nav nav-pills nav-sidebar flex-column&quot; data-widget=treeview role=menu data-accordion=false&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;statistic_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-th-large&quot;&gt;&lt;/i&gt;&lt;p&gt;Statistic&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;parameter_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Parameter&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;li class=nav-item onclick=&quot;switchContent(&#x27;sample_page&#x27;)&quot;&gt;&lt;a class=nav-link&gt;&lt;i class=&quot;nav-icon fas fa-table&quot;&gt;&lt;/i&gt;&lt;p&gt;Sample&lt;/p&gt;&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/nav&gt;&lt;/div&gt;&lt;/aside&gt;&lt;div class=content-wrapper id=statistic_page&gt;&lt;div class=content-header&gt;&lt;div class=container-fluid&gt;&lt;div class=&quot;row mb-2&quot;&gt;&lt;div class=col-sm-6&gt;&lt;h1 class=&quot;m-0 text-dark&quot;&gt;Statistic&lt;/h1&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;&lt;div class=content&gt;&lt;div class=container-fluid&gt;&lt;div class=row&gt;&lt;div class=&quot;col-sm-12 col-lg-12&quot;&gt;&lt;div class=&quot;card card-info card-outline&quot;&gt;&lt;div class=card-body&gt;&lt;div class=table-responsive&gt;&lt;table class=&quot;table table-bordered table-hover&quot;&gt;&lt;thead&gt;&lt;tr&gt;&lt;th&gt;STAT NAME&lt;/th&gt;&lt;th&gt;STAT VALUE&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr&gt;&lt;td&gt;TEST_EVAR&lt;/td&gt;&lt;td&gt;0.14117197209999977&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAE&lt;/td&gt;&lt;td&gt;0.34318000000000004&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAPE&lt;/td&gt;&lt;td&gt;0.17898000000000003&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MAX_ERROR&lt;/td&gt;&lt;td&gt;0.92869&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_MSE&lt;/td&gt;&lt;td&gt;0.28920817726666664&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_R2&lt;/td&gt;&lt;td&gt;-0.3014367977000001&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_RMSE&lt;/td&gt;&lt;td&gt;0.5377807892316967&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;TEST_WMAPE&lt;/td&gt;&lt;td&gt;0.2059080 ...
