# %% [markdown]
# # Dataframes
# The SAP HANA Python Client API for machine learning algorithms (Python Client API for ML) provides a set of client-side Python functions for accessing and querying SAP HANA data, and a set of functions for developing machine learning models.
#
# The Python Client API for ML consists of two main parts:
#
# <li>A set of machine learning APIs for different algorithms.</li>
# <li>The SAP HANA dataframe, which provides a set of methods for analyzing data in SAP HANA without bringing that data to the client.</li>
#
# This library uses the SAP HANA Python driver (hdbcli) to connect to and access SAP HANA.
# <br>
# <br>
# <img src="images/highlevel_overview2_new.png" title="Python API Overview" style="float:left;" width="300" height="50" />
# <br>
# A dataframe represents a table (or any SQL statement).  Most operations on a dataframe are designed to not bring data back from the database unless explicitly asked for.

# %%
from hana_ml import dataframe
import logging

# %% [markdown]
# ## Setup connection and data sets
# Let us load some data into a HANA table.  The data is loaded into 4 tables - full set, test set, training set, and the validation set:DBM2_RFULL_TBL, DBM2_RTEST_TBL, DBM2_RTRAINING_TBL, DBM2_RVALIDATION_TBL.
#
# The data is related with direct marketing campaigns of a Portuguese banking institution. More information regarding the data set is at https://archive.ics.uci.edu/ml/datasets/bank+marketing#.
#
# To do that, a connection is created and passed to the loader.  There is a config file, <b>config/e2edata.ini</b> that controls the connection parameters.  Please edit it to point to your hana instance.

# %%
from data_load_utils import DataSets, Settings
url, port, user, pwd = Settings.load_config("../../config/e2edata.ini")
connection_context = dataframe.ConnectionContext(url, port, user, pwd)
full_tbl, training_tbl, validation_tbl, test_tbl = DataSets.load_bank_data(connection_context)

# %% [markdown]
# ### Simple DataFrame
# <table align="left"><tr><td>
# </td><td><img src="images/Dataframes_1.png" style="float:left;" width="600" height="400" /></td></tr></table>

# %%
dataset1 = connection_context.table(training_tbl)
# Alternatively, it could be any SELECT
print(dataset1.select_statement)
# Out:
# SELECT * FROM "DBM2_RTRAINING_TBL"

# %% [markdown]
# ### Simple Operations
# #### Drop duplicates

# %%
dataset2 = dataset1.drop_duplicates()
print(dataset2.select_statement)
# Out:
# SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0"

# %% [markdown]
# #### Remove a column

# %%
dataset3 = dataset2.drop(["LABEL"])
print(dataset3.select_statement)
# Out:
# SELECT "ID", "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") AS "DT_1"

# %% [markdown]
# #### Take null values and substitute with a specific value

# %%
dataset4 = dataset2.fillna(25, ["AGE"])
print(dataset4.select_statement)
# Out:
# SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt

# %% [markdown]
# ### Bring data to client
# #### Fetch 5 rows into client as a <b>Pandas Dataframe</b>

# %%
dataset4.head(5).collect()
# Out:
#       ID  AGE          JOB   MARITAL          EDUCATION DBM_DEFAULT HOUSING  \
# 0  27178   57    housemaid   married           basic.4y          no     yes
# 1  31377   39  blue-collar  divorced           basic.9y     unknown      no
# 2   5987   34  blue-collar   married           basic.9y          no      no
# 3  12963   41  blue-collar   married            unknown          no      no
# 4   5479   32   management   married  university.degree          no      no
#
#   LOAN    CONTACT DBM_MONTH  ...   CAMPAIGN  PDAYS  PREVIOUS     POUTCOME  \
# 0   no   cellular       nov  ...          1    999         0  nonexistent
# 1   no   cellular       may  ...          2    999         0  nonexistent
# 2   no  telephone       may  ...          1    999         0  nonexistent
# 3  yes   cellular       jul  ...          1    999         0  nonexistent
# 4   no  telephone       may  ...          3    999         0  nonexistent
#
#    EMP_VAR_RATE CONS_PRICE_IDX  CONS_CONF_IDX  EURIBOR3M  NREMPLOYED  LABEL
# 0          -0.1         93.200          -42.0      4.021        5195     no
# 1          -1.8         92.893          -46.2      1.334        5099     no
# 2           1.1         93.994          -36.4      4.857        5191     no
# 3           1.4         93.918          -42.7      4.962        5228     no
# 4           1.1         93.994          -36.4      4.857        5191     no
#
# [5 rows x 22 columns]

# %%
pd1 = dataset4.head(5).collect()
print(type(pd1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Projection
# <img src="images/Projection.png" style="float:left;" width="150" height="750" />

# %%
dsp = dataset4.select("ID", "AGE", "JOB", ('"AGE"*2', "TWICE_AGE"))
dsp.head(5).collect()  # collect() brings data to the client)
# Out:
#       ID  AGE           JOB  TWICE_AGE
# 0  28115   41        admin.         82
# 1  28120   38  entrepreneur         76
# 2  28122   42    management         84
# 3  28124   50    management        100
# 4  28131   38        admin.         76

# %%
dsp.select_statement
# Out:
# 'SELECT "ID", "AGE", "JOB", "AGE"*2 AS "TWICE_AGE" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3"'

# %% [markdown]
# ### Filtering Data
# <img src="images/Filter.png" style="float:left;" width="200" height="100" />

# %%
dataset4.filter('AGE > 60').head(10).collect()
# Out:
#       ID  AGE         JOB   MARITAL            EDUCATION DBM_DEFAULT HOUSING  \
# 0  36349   67      admin.   married             basic.4y     unknown     yes
# 1  29567   68     retired   married          high.school          no     yes
# 2  38868   64     retired   married          high.school          no     yes
# 3  38879   77     retired  divorced             basic.4y          no     yes
# 4  38885   68     retired   married          high.school          no      no
# 5  38943   78     retired   married  professional.course          no      no
# 6  38946   67     retired   married             basic.4y          no      no
# 7  29669   71     retired   married    university.degree          no      no
# 8  38456   98     retired   married             basic.4y     unknown     yes
# 9  38467   61  management   married    university.degree          no      no
#
#   LOAN    CONTACT DBM_MONTH  ...   CAMPAIGN  PDAYS  PREVIOUS     POUTCOME  \
# 0   no   cellular       jun  ...          2    999         1      failure
# 1   no   cellular       apr  ...          1    999         0  nonexistent
# 2   no   cellular       nov  ...          4    999         2      failure
# 3   no   cellular       nov  ...          2    999         1      failure
# 4   no   cellular       nov  ...          2    999         1      failure
# 5   no   cellular       nov  ...          2    999         1      failure
# 6   no  telephone       nov  ...          4    999         1      failure
# 7   no   cellular       apr  ...          1    999         0  nonexistent
# 8   no   cellular       oct  ...          2    999         0  nonexistent
# 9   no   cellular       oct  ...          4    999         0  nonexistent
#
#    EMP_VAR_RATE CONS_PRICE_IDX  CONS_CONF_IDX  EURIBOR3M  NREMPLOYED  LABEL
# 0          -2.9         92.963          -40.8      1.262        5076     no
# 1          -1.8         93.075          -47.1      1.405        5099    yes
# 2          -3.4         92.649          -30.1      0.714        5017     no
# 3          -3.4         92.649          -30.1      0.714        5017    yes
# 4          -3.4         92.649          -30.1      0.714        5017    yes
# 5          -3.4         92.649          -30.1      0.718        5017    yes
# 6          -3.4         92.649          -30.1      0.718        5017     no
# 7          -1.8         93.075          -47.1      1.405        5099    yes
# 8          -3.4         92.431          -26.9      0.730        5017    yes
# 9          -3.4         92.431          -26.9      0.730        5017     no
#
# [10 rows x 22 columns]

# %%
dataset4.filter('AGE > 60').select_statement
# Out:
# 'SELECT * FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3" WHERE AGE > 60'

# %% [markdown]
# ### Sorting
# <img src="images/Sort.png" style="float:left;" width="200" height="100" />

# %%
dataset4.filter('AGE>60').sort(['AGE']).head(2).collect()
# Out:
#       ID  AGE         JOB  MARITAL            EDUCATION DBM_DEFAULT HOUSING  \
# 0  38565   61  technician  married  professional.course          no      no
# 1  40890   61     retired  married             basic.4y          no      no
#
#   LOAN    CONTACT DBM_MONTH  ...   CAMPAIGN  PDAYS  PREVIOUS     POUTCOME  \
# 0   no   cellular       oct  ...          2    999         1      failure
# 1   no  telephone       oct  ...          1    999         0  nonexistent
#
#    EMP_VAR_RATE CONS_PRICE_IDX  CONS_CONF_IDX  EURIBOR3M  NREMPLOYED  LABEL
# 0          -3.4         92.431          -26.9      0.722        5017    yes
# 1          -1.1         94.601          -49.5      0.972        4963    yes
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Simple Joins
# <img src="images/Join.png" style="float:left;" width="300" height="200" />

# %%
condition = '{}."ID"={}."ID"'.format(dataset4.quoted_name, dataset2.quoted_name)
dataset5 = dataset4.join(dataset2, condition)

# %%
dataset5.head(5).collect()
# Out:
#       ID  AGE           JOB   MARITAL            EDUCATION DBM_DEFAULT  \
# 0  28115   41        admin.   married             basic.6y          no
# 1  28120   38  entrepreneur   married  professional.course          no
# 2  28122   42    management   married              unknown          no
# 3  28124   50    management  divorced    university.degree     unknown
# 4  28131   38        admin.    single          high.school          no
#
#   HOUSING LOAN    CONTACT DBM_MONTH  ...   CAMPAIGN  PDAYS  PREVIOUS  \
# 0      no   no   cellular       apr  ...          2    999         1
# 1     yes  yes   cellular       apr  ...          2    999         1
# 2     yes   no   cellular       apr  ...          2    999         1
# 3      no   no  telephone       apr  ...          6    999         1
# 4     yes   no   cellular       apr  ...          2    999         1
#
#    POUTCOME  EMP_VAR_RATE CONS_PRICE_IDX  CONS_CONF_IDX  EURIBOR3M  \
# 0   failure          -1.8         93.075          -47.1      1.479
# 1   failure          -1.8         93.075          -47.1      1.466
# 2   failure          -1.8         93.075          -47.1      1.466
# 3   failure          -1.8         93.075          -47.1      1.466
# 4   failure          -1.8         93.075          -47.1      1.466
#
#    NREMPLOYED  LABEL
# 0        5099    yes
# 1        5099     no
# 2        5099     no
# 3        5099    yes
# 4        5099     no
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Describing a dataframe
# <img src="images/Describe.png" style="float:left;" width="300" height="200" />

# %%
dataset4.describe().collect()
# Out:
#             column  count  unique  nulls          mean           std  \
# 0               ID  16895   16895      0  21282.286652  12209.759725
# 1              AGE  16895      78      0     40.051376     10.716907
# 2         DURATION  16895    1267      0    263.965670    264.331384
# 3         CAMPAIGN  16895      35      0      2.344658      2.428449
# 4            PDAYS  16895      24      0    944.406688    226.331944
# 5         PREVIOUS  16895       7      0      0.209529      0.539450
# 6     EMP_VAR_RATE  16895      10      0     -0.038798      1.621945
# 7   CONS_PRICE_IDX  16895      26      0     93.538844      0.579189
# 8    CONS_CONF_IDX  16895      26      0    -40.334123      4.865720
# 9        EURIBOR3M  16895     283      0      3.499297      1.777986
# 10      NREMPLOYED  16895      11      0   5160.371885     75.320580
# 11             JOB  16895      12      0           NaN           NaN
# 12         MARITAL  16895       4      0           NaN           NaN
# 13       EDUCATION  16895       8      0           NaN           NaN
# 14     DBM_DEFAULT  16895       2      0           NaN           NaN
# 15         HOUSING  16895       3      0           NaN           NaN
# 16            LOAN  16895       3      0           NaN           NaN
# 17         CONTACT  16895       2      0           NaN           NaN
# 18       DBM_MONTH  16895      10      0           NaN           NaN
# 19     DAY_OF_WEEK  16895       5      0           NaN           NaN
# 20        POUTCOME  16895       3      0           NaN           NaN
# 21           LABEL  16895       2      0           NaN           NaN
#
#          min        max     median  25_percent_cont  25_percent_disc  \
# 0      5.000  41187.000  21786.000        10583.500        10583.000
# 1     17.000     98.000     38.000           32.000           32.000
# 2      0.000   4918.000    184.000          107.000          107.000
# 3      1.000     43.000      2.000            1.000            1.000
# 4      0.000    999.000    999.000          999.000          999.000
# 5      0.000      6.000      0.000            0.000            0.000
# 6     -3.400      1.400      1.100           -1.800           -1.800
# 7     92.201     94.767     93.444           93.075           93.075
# 8    -50.800    -26.900    -41.800          -42.700          -42.700
# 9      0.634      5.045      4.856            1.313            1.313
# 10  4963.000   5228.000   5191.000         5099.000         5099.000
# 11       NaN        NaN        NaN              NaN              NaN
# 12       NaN        NaN        NaN              NaN              NaN
# 13       NaN        NaN        NaN              NaN              NaN
# 14       NaN        NaN        NaN              NaN              NaN
# 15       NaN        NaN        NaN              NaN              NaN
# 16       NaN        NaN        NaN              NaN              NaN
# 17       NaN        NaN        NaN              NaN              NaN
# 18       NaN        NaN        NaN              NaN              NaN
# 19       NaN        NaN        NaN              NaN              NaN
# 20       NaN        NaN        NaN              NaN              NaN
# 21       NaN        NaN        NaN              NaN              NaN
#
#     50_percent_cont  50_percent_disc  75_percent_cont  75_percent_disc
# 0         21786.000        21786.000        32067.500        32068.000
# 1            38.000           38.000           47.000           47.000
# 2           184.000          184.000          324.000          324.000
# 3             2.000            2.000            3.000            3.000
# 4           999.000          999.000          999.000          999.000
# 5             0.000            0.000            0.000            0.000
# 6             1.100            1.100            1.400            1.400
# 7            93.444           93.444           93.994           93.994
# 8           -41.800          -41.800          -36.400          -36.400
# 9             4.856            4.856            4.961            4.961
# 10         5191.000         5191.000         5228.000         5228.000
# 11              NaN              NaN              NaN              NaN
# 12              NaN              NaN              NaN              NaN
# 13              NaN              NaN              NaN              NaN
# 14              NaN              NaN              NaN              NaN
# 15              NaN              NaN              NaN              NaN
# 16              NaN              NaN              NaN              NaN
# 17              NaN              NaN              NaN              NaN
# 18              NaN              NaN              NaN              NaN
# 19              NaN              NaN              NaN              NaN
# 20              NaN              NaN              NaN              NaN
# 21              NaN              NaN              NaN              NaN

# %%
dataset4.describe().select_statement
# Out:
# 'SELECT * FROM (SELECT "SimpleStats".*, "Percentiles"."25_percent_cont", "Percentiles"."25_percent_disc", "Percentiles"."50_percent_cont", "Percentiles"."50_percent_disc", "Percentiles"."75_percent_cont", "Percentiles"."75_percent_disc" FROM (select \'ID\' as "column", COUNT("ID") as "count", COUNT(DISTINCT "ID") as "unique", SUM(CASE WHEN "ID" is NULL THEN 1 ELSE 0 END) as "nulls", AVG("ID") as "mean", STDDEV("ID") as "std", MIN("ID") as "min", MAX("ID") as "max", MEDIAN("ID") as "median" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3" UNION ALL select \'AGE\' as "column", COUNT("AGE") as "count", COUNT(DISTINCT "AGE") as "unique", SUM(CASE WHEN "AGE" is NULL THEN 1 ELSE 0 END) as "nulls", AVG("AGE") as "mean", STDDEV("AGE") as "std", MIN("AGE") as "min", MAX("AGE") as "max", MEDIAN("AGE") as "median" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3" UNION ALL select \'DURATION\' as "column", COUNT("DURATION") as "count", COUNT(DISTINCT "DURATION") as "unique", SUM(CASE WHEN "DURATION" is NULL THEN 1 ELSE 0 END) as "nulls", AVG("DURATION") as "mean", STDDEV("DURATION") as "std", MIN("DURATION") as "min", MAX("DURATION") as "max", MEDIAN("DURATION") as "median" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3" UNION ALL select \'CAMPAIGN\' as "column", COUNT("CAMPAIGN") as "count", COUNT(DISTINCT "CAMPAIGN") as "unique", SUM(CASE WHEN "CAMPAIGN" is NULL THEN 1 ELSE 0 END) as "nulls", AVG("CAMPAIGN") as "mean", STDDEV("CAMPAIGN") as "std", MIN("CAMPAIGN") as "min", MAX("CAMPAIGN") as "max", MEDIAN("CAMPAIGN") as "median" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3" UNION ALL select \'PDAYS\' as "column", COUNT("PDAYS") as "count", COUNT(DISTINCT "PDAYS") as "unique", SUM(CASE WHEN "PDAYS" is NULL THEN 1 ELSE 0 END) as "nulls", AVG("PDAYS") as "mean", STDDEV("PDAYS") as "std", MIN("PDAYS") as "min", MAX("PDAYS") as "max", MEDIAN("PDAYS") as "median" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARITAL", "EDUCATION", "DBM_DEFAULT", "HOUSING", "LOAN", "CONTACT", "DBM_MONTH", "DAY_OF_WEEK", "DURATION", "CAMPAIGN", "PDAYS", "PREVIOUS", "POUTCOME", "EMP_VAR_RATE", "CONS_PRICE_IDX", "CONS_CONF_IDX", "EURIBOR3M", "NREMPLOYED", "LABEL" FROM (SELECT DISTINCT * FROM (SELECT * FROM "DBM2_RTRAINING_TBL") AS "DT_0") dt) AS "DT_3" UNION ALL select \'PREVIOUS\' as "column", COUNT("PREVIOUS") as "count", COUNT(DISTINCT "PREVIOUS") as "unique", SUM(CASE WHEN "PREVIOUS" is NULL THEN 1 ELSE 0 END) as "nulls", AVG("PREVIOUS") as "mean", STDDEV("PREVIOUS") as "std", MIN("PREVIOUS") as "min", MAX("PREVIOUS") as "max", MEDIAN("PREVIOUS") as "median" FROM (SELECT "ID", COALESCE("AGE", 25) AS "AGE", "JOB", "MARIT ...

# %% [markdown]
# ### Saving a dataframe

# %%
dataset4.head(10).collect()
# Out:
#       ID  AGE           JOB   MARITAL            EDUCATION DBM_DEFAULT  \
# 0  27178   57     housemaid   married             basic.4y          no
# 1  31377   39   blue-collar  divorced             basic.9y     unknown
# 2   5987   34   blue-collar   married             basic.9y          no
# 3  12963   41   blue-collar   married              unknown          no
# 4   5479   32    management   married    university.degree          no
# 5  33491   53    technician   married  professional.course          no
# 6  30259   56  entrepreneur   married    university.degree          no
# 7  35092   36    management  divorced    university.degree          no
# 8   7744   51   blue-collar   married              unknown     unknown
# 9  38755   29        admin.    single    university.degree          no
#
#    HOUSING     LOAN    CONTACT DBM_MONTH  ...   CAMPAIGN  PDAYS  PREVIOUS  \
# 0      yes       no   cellular       nov  ...          1    999         0
# 1       no       no   cellular       may  ...          2    999         0
# 2       no       no  telephone       may  ...          1    999         0
# 3       no      yes   cellular       jul  ...          1    999         0
# 4       no       no  telephone       may  ...          3    999         0
# 5       no       no   cellular       may  ...          5    999         1
# 6      yes       no   cellular       apr  ...          1    999         0
# 7  unknown  unknown   cellular       may  ...          1    999         0
# 8      yes       no  telephone       may  ...          3    999         0
# 9       no      yes   cellular       nov  ...          1      3         1
#
#       POUTCOME  EMP_VAR_RATE CONS_PRICE_IDX  CONS_CONF_IDX  EURIBOR3M  \
# 0  nonexistent          -0.1         93.200          -42.0      4.021
# 1  nonexistent          -1.8         92.893          -46.2      1.334
# 2  nonexistent           1.1         93.994          -36.4      4.857
# 3  nonexistent           1.4         93.918          -42.7      4.962
# 4  nonexistent           1.1         93.994          -36.4      4.857
# 5      failure          -1.8         92.893          -46.2      1.291
# 6  nonexistent          -1.8         93.075          -47.1      1.365
# 7  nonexistent          -1.8         92.893          -46.2      1.250
# 8  nonexistent           1.1         93.994          -36.4      4.864
# 9      success          -3.4         92.649          -30.1      0.715
#
#    NREMPLOYED  LABEL
# 0        5195     no
# 1        5099     no
# 2        5191     no
# 3        5228     no
# 4        5191     no
# 5        5099     no
# 6        5099     no
# 7        5099     no
# 8        5191     no
# 9        5017    yes
#
# [10 rows x 22 columns]

# %%
dataset4.count()
# Out:
# 16895

# %%
dataset4.save("#MYTEST2")

# %%
dataset8 = connection_context.table("#MYTEST2")

# %%
dataset8.head(10).collect()
# Out:
#       ID  AGE           JOB   MARITAL            EDUCATION DBM_DEFAULT  \
# 0  27178   57     housemaid   married             basic.4y          no
# 1  31377   39   blue-collar  divorced             basic.9y     unknown
# 2   5987   34   blue-collar   married             basic.9y          no
# 3  12963   41   blue-collar   married              unknown          no
# 4   5479   32    management   married    university.degree          no
# 5  33491   53    technician   married  professional.course          no
# 6  30259   56  entrepreneur   married    university.degree          no
# 7  35092   36    management  divorced    university.degree          no
# 8   7744   51   blue-collar   married              unknown     unknown
# 9  38755   29        admin.    single    university.degree          no
#
#    HOUSING     LOAN    CONTACT DBM_MONTH  ...   CAMPAIGN  PDAYS  PREVIOUS  \
# 0      yes       no   cellular       nov  ...          1    999         0
# 1       no       no   cellular       may  ...          2    999         0
# 2       no       no  telephone       may  ...          1    999         0
# 3       no      yes   cellular       jul  ...          1    999         0
# 4       no       no  telephone       may  ...          3    999         0
# 5       no       no   cellular       may  ...          5    999         1
# 6      yes       no   cellular       apr  ...          1    999         0
# 7  unknown  unknown   cellular       may  ...          1    999         0
# 8      yes       no  telephone       may  ...          3    999         0
# 9       no      yes   cellular       nov  ...          1      3         1
#
#       POUTCOME  EMP_VAR_RATE CONS_PRICE_IDX  CONS_CONF_IDX  EURIBOR3M  \
# 0  nonexistent          -0.1         93.200          -42.0      4.021
# 1  nonexistent          -1.8         92.893          -46.2      1.334
# 2  nonexistent           1.1         93.994          -36.4      4.857
# 3  nonexistent           1.4         93.918          -42.7      4.962
# 4  nonexistent           1.1         93.994          -36.4      4.857
# 5      failure          -1.8         92.893          -46.2      1.291
# 6  nonexistent          -1.8         93.075          -47.1      1.365
# 7  nonexistent          -1.8         92.893          -46.2      1.250
# 8  nonexistent           1.1         93.994          -36.4      4.864
# 9      success          -3.4         92.649          -30.1      0.715
#
#    NREMPLOYED  LABEL
# 0        5195     no
# 1        5099     no
# 2        5191     no
# 3        5228     no
# 4        5191     no
# 5        5099     no
# 6        5099     no
# 7        5099     no
# 8        5191     no
# 9        5017    yes
#
# [10 rows x 22 columns]

# %%
dataset8.count()
# Out:
# 16895
