# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
from hana_ml import dataframe
from data_load_utils import Settings

# %% [markdown]
# ## Generate Test Series

# %%
def geometric_brownian_motion(T = 1, N = 2, mu = -0.01, sigma = 0.001, S0 = 2):        
    dt = float(T)/N
    t = np.linspace(0, T, N)
    W = np.random.standard_normal(size = N) 
    W = np.cumsum(W)*np.sqrt(dt) ### standard brownian motion ###
    X = (mu-0.5*sigma**2)*t + sigma*W 
    S = S0*np.exp(X) ### geometric brownian motion ###
    return S

dates = pd.date_range('2010-01-01', '2018-03-10',freq='H')
T = (dates.max()-dates.min()).days / 365
N = dates.size
start_price = 1000
y = pd.DataFrame()
y['INDEX'] = dates
y['Y'] = geometric_brownian_motion(T, N, sigma=0.1, S0=start_price)
y.set_index("INDEX").plot()
# Out:
# <AxesSubplot:xlabel='INDEX'>

# %%
url, port, user, pwd = Settings.load_config("../../config/e2edata.ini")
connection_context = dataframe.ConnectionContext(url, port, user, pwd)

# %% [markdown]
# ## Upload to HANA DB

# %%
import time
start = time.time()
hana_df = dataframe.create_dataframe_from_pandas(connection_context, y, 'ARIMA_TEST', force=True, batch_size=50000)
print(time.time() - start)
# Out:
#  50%|█████     | 1/2 [00:03<00:03,  3.97s/it]
#                     INDEX           Y
# 71758 2018-03-09 22:00:00  774.850349
# 71759 2018-03-09 23:00:00  774.141913
# 71760 2018-03-10 00:00:00  775.009508
# 100%|██████████| 2/2 [00:05<00:00,  2.72s/it]
# 6.713771104812622

# %%
hana_df.collect().set_index("INDEX").plot()
# Out:
# <AxesSubplot:xlabel='INDEX'>

# %%
y.tail(3)
# Out:
#                     INDEX           Y
# 71758 2018-03-09 22:00:00  774.850349
# 71759 2018-03-09 23:00:00  774.141913
# 71760 2018-03-10 00:00:00  775.009508

# %%
hana_df.collect().tail(3)
# Out:
#                     INDEX           Y
# 71758 2017-08-03 20:00:00  702.366172
# 71759 2017-08-03 21:00:00  702.885450
# 71760 2017-08-03 22:00:00  703.281054

# %%
df_pal = dataframe.DataFrame(connection_context, 'select * from ARIMA_TEST').select('INDEX','Y')

# %%
print (df_pal.count(), df_pal.columns)
# Out:
# 71761 ['INDEX', 'Y']

# %%
from hana_ml.visualizers import m4_sampling
import timeit
years = mdates.YearLocator()

# %%
# %matplotlib inline
start=timeit.default_timer()
df_raw = df_pal.collect()
df_raw.set_index(df_raw.columns[0], inplace=True)
df_raw=df_raw.astype(float)
ax = df_raw.plot()
ax.xaxis.set_major_locator(years)
print(timeit.default_timer()-start)
# Out:
# 308.65884926891886

# %%
# %matplotlib inline
start=timeit.default_timer()
df_sample = m4_sampling.m4_sampling(df_pal,200)
df_mod = df_sample.collect()
df_mod.set_index(df_mod.columns[0], inplace=True)
df_mod.sort_index(inplace=True)
df_mod=df_mod.astype(float)
ax = df_mod.plot()
ax.xaxis.set_major_locator(years)
print(timeit.default_timer()-start)
# Out:
# 4.627003398956731
